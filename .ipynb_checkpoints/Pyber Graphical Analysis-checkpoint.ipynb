# %%
# Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
city_df['ID'] = np.arange(1, len(city_df)+1, 1)

# %%
# import file using pandas

city_file = os.path.join('raw_data', 'city_data.csv')
ride_file = os.path.join('raw_data', 'ride_data.csv')

city_df = pd.read_csv(city_file)
ride_df = pd.read_csv(ride_file)

city_df = city_df.drop_duplicates('city', keep = 'first')
#merge
merged_df = city_df.merge(ride_df, on = 'city')

# %%
#len(merged_df[merged_df['city'] == 'Port James']['ride_id'].unique())

# %%
#ride_df

# %%
#ride_df[ride_df['city'] == 'Port James']

# %%
# city_new = city_df.drop_duplicates()
# len(city_new)

# %%
len(ride_df['ride_id'].unique())
# Out:
# 2375

# %%
color_scheme = {'Gold':'#FFD700', 'Light Sky Blue':'#87CEFA', 'Light Coral':'#F08080'}
sns.palplot(sns.color_palette(color_scheme.values()))
plt.show()

# %%
#building dataseries
by_city = merged_df.groupby('city')

# var holding avg fare by city
avg_fare = by_city.mean()['fare']

#var holding rides by city
ride_count = by_city['ride_id'].count()

# num of drivers
driver_count = by_city.mean()['driver_count']

city_df = city_df.drop_duplicates('city', keep = 'first')
city_type = city_df.set_index('city')['type']

city_info = pd.DataFrame({
    "Number of Rides": ride_count,
    "Average Fare": avg_fare,
    "Number of Drivers": driver_count,
    "Type of City": city_type
})
city_info.sort_values('Number of Drivers', ascending = False)
rural = city_info[city_info['Type of City'] == 'Rural']
suburban = city_info[city_info['Type of City'] == 'Suburban']
urban = city_info[city_info['Type of City'] == 'Urban']

#city_info = city_info.sort_values('Number of Drivers')
#Color Dictionary 
city_color = {'Urban': color_scheme['Gold'], 'Suburban': color_scheme['Light Sky Blue'], 'Rural': color_scheme['Light Coral']}

# #plt.scatter( data['a'], data['b'], color=[ color_dict[i] for i in data['c'] ] )

# plt.title('Pyber Ride Sharing Data')
# plt.xlabel('Number of Rides per City')
# plt.ylabel('Average Fair per City')
# labels = [x for x in city_info['Type of City'].unique()]
# #for x in labels:
sns.set_palette(color_scheme.values())    
plt.scatter(rural['Number of Rides'], rural['Average Fare'], s = rural['Number of Drivers']*10, color = city_color['Rural'], edgecolor = 'black', label = 'Rural', alpha = .75)
plt.scatter(suburban['Number of Rides'], suburban['Average Fare'], s = suburban['Number of Drivers']*10, color = city_color['Suburban'], edgecolor = 'black', label = 'Suburban', alpha = .75)
plt.scatter(urban['Number of Rides'], urban['Average Fare'], s = urban['Number of Drivers']*10, color = city_color['Urban'], edgecolor = 'black', label = 'Urban', alpha = .75)
# #plt.legend(, labels)


#sns.set_palette(color_scheme.values())
# Create scatterplot of dataframe
sns.set_palette(color_scheme.values())
# sns.lmplot('Number of Rides', # Horizontal axis
#            'Average Fare', # Vertical axis
#            fit_reg=False, # Don't fix a regression line
#            hue="Type of City",
#            legend = True,
#            legend_out = False,
#            size = 'Number of Drivers', 
#            data = city_info # Data source
#         ) 
plt.legend()
plt.show()

# %%
merged_df.drop_duplicates('city')
# Out:
#             city  driver_count      type                 date   fare  \
# 1902  Port James            15  Suburban  2016-12-04 06:16:36  15.77
# 1903  Port James            15  Suburban  2016-05-16 21:25:03  26.26
# 1904  Port James            15  Suburban  2016-01-04 22:46:29  20.25
# 1905  Port James            15  Suburban  2016-01-27 19:25:42  21.86
# 1906  Port James            15  Suburban  2016-05-30 15:35:47  38.05
# 1907  Port James            15  Suburban  2016-06-05 02:06:00  14.67
# 1908  Port James            15  Suburban  2016-01-05 05:44:27  26.30
# 1909  Port James            15  Suburban  2016-04-24 17:14:17  22.79
# 1910  Port James            15  Suburban  2016-04-02 08:25:37  32.73
# 1911  Port James            15  Suburban  2016-06-10 07:17:00  44.75
# 1912  Port James            15  Suburban  2016-02-07 12:25:28  40.07
# 1913  Port James            15  Suburban  2016-01-11 23:27:53  39.66
# 1914  Port James            15  Suburban  2016-01-10 23:39:42  32.32
# ...

# %% [markdown]
# ## Total Fares by City Type

# %%
by_type = merged_df.groupby('type')['type', 'fare', 'ride_id', 'driver_count']

fare_sum = by_type.sum()['fare']
fare_sum
labels = fare_sum.index
explode = [.3 , 0, 0]
plt.pie(fare_sum, startangle = 90, explode = explode, labels = labels, autopct = "%1.1f%%", shadow = True, wedgeprops = {'linewidth': .5, 'edgecolor': 'black'})
plt.title('% of Total Fares by City Type')
plt.axis('equal')
plt.show()

# %%
ride_sum = by_type.count()['ride_id']
labels = ride_sum.index
explode = [.3 , 0, 0]
plt.pie(ride_sum, startangle = 90, explode = explode, labels = labels, autopct = "%1.1f%%", shadow = True, wedgeprops = {'linewidth': .5, 'edgecolor': 'black'})
plt.title('% of Total Rides by City Type')
plt.axis('equal')
plt.show()

# %%
driver_sum = by_type.sum()['driver_count']
labels = driver_sum.index
explode = [.3 , 0, 0]
plt.pie(driver_sum, startangle = 90, explode = explode, labels = labels, autopct = "%1.1f%%", shadow = True, wedgeprops = {'linewidth': .5, 'edgecolor': 'black'})
plt.title('% of Total Drivers by City Type')
plt.axis('equal')
plt.show()
